# %% [markdown]
# # Part 1: Environment Setup
#
# This section mounts Google Drive, sets up project directories, downloads the MedMNIST dataset from Zenodo, installs dependencies, imports all required libraries, and defines the global configuration dictionary.

# %%
# ── Google Drive Setup ───────────────────────────────────────────────────────
import os
from google.colab import drive

# Mount Google Drive to access project files and saved models
drive.mount('/content/drive')

# Define top-level project and data directories
DRIVE_DIR = '/content/drive/MyDrive/GQMoE'
DATA_DIR  = f'{DRIVE_DIR}/data'
os.makedirs(DATA_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# ── MedMNIST Dataset Download ────────────────────────────────────────────────
ZENODO_REC = "10519652"

# All 18 MedMNIST datasets to download from Zenodo
FILES = [
    "pathmnist.npz", "chestmnist.npz", "dermamnist.npz", "octmnist.npz",
    "pneumoniamnist.npz", "retinamnist.npz", "breastmnist.npz", "bloodmnist.npz",
    "tissuemnist.npz", "organamnist.npz", "organcmnist.npz", "organsmnist.npz",
    "organmnist3d.npz", "nodulemnist3d.npz", "adrenalmnist3d.npz",
    "fracturemnist3d.npz", "vesselmnist3d.npz", "synapsemnist3d.npz",
]

# Skip files already on disk; otherwise download via curl with resume support
for fname in FILES:
    dest = os.path.join(DATA_DIR, fname)
    if os.path.exists(dest):
        print(f"[skip]     {fname}")
        continue
    url = f"https://zenodo.org/records/{ZENODO_REC}/files/{fname}?download=1"
    print(f"[download] {fname}")
    os.system(f'curl -L -C - -o "{dest}" "{url}"')

print(f"\nAll files ready in: {DATA_DIR}")
# Out:
# [skip]     pathmnist.npz
# [skip]     chestmnist.npz
# [skip]     dermamnist.npz
# [skip]     octmnist.npz
# [skip]     pneumoniamnist.npz
# [skip]     retinamnist.npz
# [skip]     breastmnist.npz
# [skip]     bloodmnist.npz
# [skip]     tissuemnist.npz
# [skip]     organamnist.npz
# [skip]     organcmnist.npz
# [skip]     organsmnist.npz
# [skip]     organmnist3d.npz
# [skip]     nodulemnist3d.npz
# [skip]     adrenalmnist3d.npz
# [skip]     fracturemnist3d.npz
# [skip]     vesselmnist3d.npz
# [skip]     synapsemnist3d.npz
#
# All files ready in: /content/drive/MyDrive/GQMoE/data

# %%
requirements_path = f"{DRIVE_DIR}/requirements.txt"
# !pip install -r "{requirements_path}"
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cpu.html
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (0.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 6)) (11.3.0)
# Collecting fire (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 7))
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 9)) (0.25.0+cu128)
# Collecting medmnist (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 10))
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Collecting torch_geometric (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 11))
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.8 MB/s eta 0:00:00
# Collecting pennylane (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading pennylane-0.44.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (0.25.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 14)) (3.10.0)
# Collecting torch-scatter (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 16))
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcpu/torch_scatter-2.1.2%2Bpt210cpu-cp312-cp312-linux_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.4/682.4 kB 21.3 MB/s eta 0:00:00
# Collecting torch-sparse (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 17))
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcpu/torch_sparse-0.6.18%2Bpt210cpu-cp312-cp312-linux_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 95.6 MB/s eta 0:00:00
# Collecting torch-cluster (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 18))
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcpu/torch_cluster-1.6.3%2Bpt210cpu-cp312-cp312-linux_x86_64.whl (828 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.2/828.2 kB 99.9 MB/s eta 0:00:00
# Collecting torch-spline-conv (from -r /content/drive/MyDrive/GQMoE/requirements.txt (line 19))
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcpu/torch_spline_conv-1.2.2%2Bpt210cpu-cp312-cp312-linux_x86_64.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.9/306.9 kB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 2)) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 4)) (0.5)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (1.5.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (3.13.5)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (3.6.0)
# Collecting rustworkx>=0.14.0 (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (1.8.0)
# Collecting appdirs (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (6.2.6)
# Collecting pennylane-lightning>=0.44 (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (0.13.3)
# Collecting diastatic-malt==2.15.2 (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt==2.15.2->pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (1.6.3)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (8.3.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<7,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (2.57.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 14)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 14)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (4.0.12)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12))
#   Downloading scipy_openblas32-0.3.31.188.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 11)) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 13)) (5.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt==2.15.2->pennylane->-r /content/drive/MyDrive/GQMoE/requirements.txt (line 12)) (0.46.3)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 17.8 MB/s eta 0:00:00
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.0 MB/s eta 0:00:00
# Downloading pennylane-0.44.1-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 20.4 MB/s eta 0:00:00
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 94.8 MB/s eta 0:00:00
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 26.2 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 125.9 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 154.4 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading scipy_openblas32-0.3.31.188.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 47.8 MB/s eta 0:00:00
# Installing collected packages: appdirs, torch-spline-conv, torch-scatter, scipy-openblas32, rustworkx, fire, autoray, torch-sparse, torch-cluster, torch_geometric, diastatic-malt, medmnist, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 fire-0.7.1 medmnist-3.0.2 pennylane-0.44.1 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.188.0 torch-cluster-1.6.3+pt210cpu torch-scatter-2.1.2+pt210cpu torch-sparse-0.6.18+pt210cpu torch-spline-conv-1.2.2+pt210cpu torch_geometric-2.7.0

# %%
# Standard library
import os
import json
import math

# Core numeric and ML
import torch
import numpy as np
import torch.nn.functional as F

# Quantum computing
import pennylane as qml

# Plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Dataset and graph utilities
from torch.utils.data import Dataset
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import knn_graph, global_mean_pool, GlobalAttention, GCNConv, GATConv, SAGEConv, GINConv
from torchvision import transforms

# Evaluation metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# %%
config = {
    # Data
    "file_path":     f"{DATA_DIR}/octmnist.npz",

    # Graph pipeline
    "patch_size":    4,      # height/width of each image patch (must divide image dims)
    "k_neighbors":   8,      # number of nearest neighbors per node in knn_graph

    # DataLoader
    "batch_size":    32,

    # GlobalSummary
    "pool_method":   "mean", # "mean" or "attn"
    "attn_hidden":   64,     # hidden dim of attention gate (used only when pool_method="attn")

    # QuantumRouter
    "n_qubits":      8,      # number of qubits = number of experts
    "n_layers":      2,      # variational circuit depth

    # Expert GNNs
    "expert_hidden": 64,     # hidden dim inside each expert GNN
    "expert_out":    128,    # output dim of each expert (= MoE output dim)
    "top_k":         2,      # how many experts are activated per sample

    # Iterative refinement
    "n_iterations":  4,      # number of GlobalSummary → QuantumRouter → MoE passes

    # Classifier
    "n_classes":     4,      # number of output classes (bloodmnist has 8 classes)
    "clf_hidden":    256,    # hidden dim of the MLP classification head
    "dropout":       0.3,

    # Training
    "epochs":        400,
    "warmup_epochs": 2,      # epochs for linear LR warmup (then cosine annealing)
    "lr":            1e-3,
    "weight_decay":  1e-4,

    # Data augmentation (training only)
    "aug_hflip":     False,   # random horizontal flip (p=0.5)
    "aug_vflip":     False,   # random vertical flip (p=0.5)
    "aug_rotation":  0,     # max rotation degrees (0 to disable)

    # W&B
    "wandb_project": "GQMoE",
    "wandb_run":     "gqmoe-octmnist-v1",

    # Resume training from a checkpoint saved in Drive.
    # Set to the full path of checkpoint.pt to continue a previous run,
    # or None to start fresh.
    # Example: f"{DRIVE_DIR}/checkpoint.pt"
    "resume_ckpt":   f"{DRIVE_DIR}/checkpoint.pt",

    # If resuming, load optimizer state and LR from checkpoint, bypassing warmup.
    # Overrides loading best_model.pt if True.
    "resume_optimizer_state": True
}

# %% [markdown]
# # Part 2: Data Pipeline
#
# This section converts raw MedMNIST images into graph-structured data. Each image is divided into fixed-size patches (nodes), and a k-NN graph is built from patch feature similarity. Data augmentation is applied during training only.

# %% [markdown]
# ## Image-to-Graph Pipeline
#
# `MedMNISTGraphPipeline` extracts non-overlapping patches from an image tensor and constructs a k-NN graph where each patch is a node.

# %%
# The Image-to-Graph Pipeline
class MedMNISTGraphPipeline:
    def __init__(self, patch_size, k_neighbors):
        '''
        Args:
            patch_size (int): height or width of a patch
            k_neighbors (int): number of nearest neighbors to find around a node
        '''
        self.patch_size = patch_size
        self.k_neighbors = k_neighbors

    def extract_patches(self, img_tensor):
        c, h, w = img_tensor.shape
        p = self.patch_size

        assert h % p == 0 and w % p == 0, "Patch size not suitable."

        # Unfold into patches: [C, H/P, W/P, P, P]
        patches = img_tensor.unfold(1, p, p).unfold(2, p, p)
        num_patches = patches.shape[1] * patches.shape[2]

        # Reshape to [Num_Patches, C*P*P]
        patches = patches.contiguous().view(c, num_patches, p * p)
        patches = patches.permute(1, 0, 2).reshape(num_patches, -1)
        return patches

    def process(self, img_tensor):
        x = self.extract_patches(img_tensor)
        edge_index = knn_graph(x, k=self.k_neighbors, loop=False)
        return Data(x=x, edge_index=edge_index)

# %% [markdown]
# ## Data Augmentation
#
# `build_transform` assembles a torchvision augmentation pipeline from the config flags. It is applied only to the training split.

# %%
# ── Build augmentation pipeline from config (training only) ───────────────────
def build_transform(config):
    aug_list = []
    # Add each augmentation only if enabled in config
    if config.get("aug_hflip", False):
        aug_list.append(transforms.RandomHorizontalFlip(p=0.5))
    if config.get("aug_vflip", False):
        aug_list.append(transforms.RandomVerticalFlip(p=0.5))
    if config.get("aug_rotation", 0) > 0:
        aug_list.append(transforms.RandomRotation(degrees=config["aug_rotation"]))
    # Return composed transform, or None if no augmentation is configured
    return transforms.Compose(aug_list) if aug_list else None

# %% [markdown]
# ## Dataset Class
#
# `NPZMedMNISTGraphDataset` wraps a MedMNIST `.npz` file. On each `__getitem__` call it converts the image to a PyG `Data` graph object, optionally applying augmentation for the training split.

# %%
class NPZMedMNISTGraphDataset(Dataset):
    def __init__(self, npz_path, split, pipeline, transform=None):
        """
        Args:
            npz_path (str): Path to the MedMNIST .npz file.
            split (str): One of 'train', 'val', or 'test'.
            pipeline: The graph conversion pipeline.
            transform: Optional torchvision transforms applied before graph conversion.
                       Should only be passed for the training split.
        """
        self.pipeline = pipeline
        self.transform = transform

        data = np.load(npz_path)
        self.images = data[f'{split}_images']
        self.labels = data[f'{split}_labels']

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        label = self.labels[idx]

        img_tensor = torch.from_numpy(img).float()

        # Handle different image dimensions (grayscale vs. RGB)
        if img_tensor.ndim == 2:
            # Grayscale image (H, W) -> (C, H, W) with C=1
            img_tensor = img_tensor.unsqueeze(0)
        elif img_tensor.ndim == 3:
            # RGB image (H, W, C) -> (C, H, W)
            img_tensor = img_tensor.permute(2, 0, 1)
        else:
            raise ValueError(f"Unsupported image dimensions: {img_tensor.ndim}")

        # Normalize to [0, 1]
        img_tensor = img_tensor / 255.0

        # Apply augmentation (training only)
        if self.transform is not None:
            img_tensor = self.transform(img_tensor)

        graph_data = self.pipeline.process(img_tensor)

        label_val = label.item() if label.size == 1 else label[0]
        graph_data.y = torch.tensor([label_val], dtype=torch.long)

        return graph_data

# %% [markdown]
# ## DataLoaders
#
# Instantiate the pipeline, build all three dataset splits, and wrap them in PyG `DataLoader`s. Training data is shuffled; validation and test are not.

# %%
# Initialize Pipeline
pipeline = MedMNISTGraphPipeline(patch_size=config["patch_size"], k_neighbors=config["k_neighbors"])

# Build augmentation transform from config (applied to training split only)
train_transform = build_transform(config)

# Initialize Datasets
train_dataset = NPZMedMNISTGraphDataset(npz_path=config["file_path"], split='train', pipeline=pipeline, transform=train_transform)
val_dataset   = NPZMedMNISTGraphDataset(npz_path=config["file_path"], split='val',   pipeline=pipeline)
test_dataset  = NPZMedMNISTGraphDataset(npz_path=config["file_path"], split='test',  pipeline=pipeline)

# Create PyG DataLoaders; shuffle train for better generalization
train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=config["batch_size"], shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=config["batch_size"], shuffle=False)

# %% [markdown]
# # Part 3: Model Architecture
#
# This section defines all components of the GQMoE (Graph Quantum Mixture-of-Experts) model:
# - **GlobalSummary** — pools node features into a single graph-level vector
# - **QuantumRouter** — uses a variational quantum circuit to compute expert routing weights
# - **Expert GNNs** — a diverse pool of graph neural networks (GCN, GAT, SAGE, GIN)
# - **QuantumMoELayer** — routes each sample through the top-k experts and aggregates outputs
# - **NodeUpdater** — injects graph-level MoE output back into node features for iterative refinement
# - **IterativeGQMoE** — runs multiple GlobalSummary → QuantumRouter → MoE passes
# - **GQMoEClassifier** — adds an attention pooling layer and MLP classification head

# %% [markdown]
# ## 3.1 Global Summary
#
# `GlobalSummary` collapses all node features in a graph into one fixed-size vector `g` using either mean pooling or learned attention pooling. This vector is the input to the quantum router.

# %%
class GlobalSummary(torch.nn.Module):
    """
    Produce a graph-level global vector g from node features x in a PyG Batch.
    """
    def __init__(self, in_dim: int, method: str="mean", attn_hidden: int=64):
        super().__init__()
        assert method in ["mean", "attn"]
        self.method = method

        if method == "attn":
            gate_nn = torch.nn.Sequential(
                torch.nn.Linear(in_dim, attn_hidden),
                torch.nn.ReLU(),
                torch.nn.Linear(attn_hidden, 1)
            )
            self.pool = GlobalAttention(gate_nn=gate_nn)

    def forward(self, batch_data):
        x = batch_data.x    # [total_nodes_in_batch, in_dim]
        batch = batch_data.batch  # [total_nodes_in_batch], graph id for each node
        if self.method == "mean":
            g = global_mean_pool(x, batch)  #[batch_size, in_dim]
        else:
            g = self.pool(x, batch)  #[batch_size, in_dim]
        return g

# %%
# ── Derive feature_dim from data & instantiate GlobalSummary ──────────────────
# Fetch one mini-batch to determine node feature dimensionality (C * patch_size^2)
sample_batch = next(iter(train_loader))
feature_dim = sample_batch.x.shape[1]   # C * patch_size^2
print(f"feature_dim: {feature_dim}")

# Instantiate with pooling method from config
summary_module = GlobalSummary(
    in_dim      = feature_dim,
    method      = config["pool_method"],
    attn_hidden = config["attn_hidden"],
)
# Out:
# feature_dim: 16

# %% [markdown]
# ## 3.2 Quantum Router
#
# `QuantumRouter` maps the global summary vector `g` to expert routing weights via a Variational Quantum Circuit (VQC). A classical encoder compresses `g` to qubit angles, which are embedded into the circuit via `AngleEmbedding`. Variational `RY` layers with ring `CNOT` entanglement learn the routing function. Pauli-Z measurements yield per-expert scores that are softmax-normalized into routing probabilities.

# %%
class QuantumRouter(torch.nn.Module):
    """
    Variational Quantum Circuit (VQC) routing layer for MoE.

    Flow:
      g [B, feature_dim]
        → Classical encoder (Linear → Tanh) → angles [B, n_qubits]
        → VQC: AngleEmbedding (Ry) + variational Ry/CNOT layers
        → Measure ⟨Z_i⟩ on each qubit           → [B, n_qubits]  (values in [-1, 1])
        → Softmax                                → routing_weights [B, n_qubits]

    n_experts == n_qubits: each qubit's measurement routes to one expert.
    """

    def __init__(self, feature_dim: int, n_qubits: int = 4, n_layers: int = 2):
        super().__init__()
        self.n_qubits = n_qubits

        # ── 1. Classical encoder: compress global vector to qubit angles ──────
        # Tanh keeps outputs in [-1, 1]; scaled to [-π, π] inside the circuit.
        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(feature_dim, n_qubits),
            torch.nn.Tanh(),
        )

        # ── 2. Build VQC ──────────────────────────────────────────────────────
        dev = qml.device("default.qubit", wires=n_qubits)

        @qml.qnode(dev, interface="torch", diff_method="backprop")
        def circuit(inputs, weights):
            # Angle encoding: Ry(x_i * π) encodes each classical value onto a qubit
            qml.AngleEmbedding(inputs * math.pi, wires=range(n_qubits), rotation="Y")

            # Variational layers: trainable Ry rotations + ring CNOT entanglement
            for layer_idx in range(n_layers):
                for qubit in range(n_qubits):
                    qml.RY(weights[layer_idx, qubit], wires=qubit)
                for qubit in range(n_qubits):
                    qml.CNOT(wires=[qubit, (qubit + 1) % n_qubits])

            # Measure Pauli-Z expectation on every qubit → values in [-1, 1]
            return [qml.expval(qml.PauliZ(q)) for q in range(n_qubits)]

        # TorchLayer exposes VQC weights as nn.Parameters (gradient-compatible)
        weight_shapes = {"weights": (n_layers, n_qubits)}
        self.vqc = qml.qnn.TorchLayer(circuit, weight_shapes)

    def forward(self, g: torch.Tensor) -> torch.Tensor:
        """
        Args:
            g: [B, feature_dim]  global graph vector from GlobalSummary
        Returns:
            routing_weights: [B, n_qubits]  softmax routing probabilities
        """
        angles       = self.encoder(g)         # [B, n_qubits], in [-1, 1]
        measurements = self.vqc(angles)         # [B, n_qubits], in [-1, 1]
        routing_weights = torch.softmax(measurements, dim=-1)  # [B, n_qubits], sums to 1
        return routing_weights

# %%
# ── Smoke test ────────────────────────────────────────────────────────────────
quantum_router = QuantumRouter(
    feature_dim=feature_dim,
    n_qubits=config["n_qubits"],
    n_layers=config["n_layers"],
)

for batch in train_loader:
    g = summary_module(batch)                        # [B, 1372]
    routing_weights = quantum_router(g)              # [B, n_qubits]

    print("g shape:               ", g.shape)
    print("routing_weights shape: ", routing_weights.shape)
    print("routing_weights[0]:    ", routing_weights[0].detach().numpy())
    print("sum (should be 1.0):   ", routing_weights[0].sum().item())
    break
# Out:
# g shape:                torch.Size([32, 16])
# routing_weights shape:  torch.Size([32, 8])
# routing_weights[0]:     [0.13620122 0.1109736  0.13997786 0.11387111 0.1042344  0.12373745
#  0.14322194 0.12778239]
# sum (should be 1.0):    0.9999999403953552

# %% [markdown]
# ## 3.3 Expert GNNs
#
# Each expert is a distinct 2-layer GNN architecture. Using four architectures (GCN, GAT, SAGE, GIN) in narrow and wide variants encourages specialization: different experts learn complementary structural patterns.

# %%
class GCNExpert(torch.nn.Module):
    """2-layer Graph Convolutional Network."""
    def __init__(self, in_dim, hidden_dim, out_dim):
        super().__init__()
        self.conv1 = GCNConv(in_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, out_dim)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return global_mean_pool(x, batch)          # [B, out_dim]

# %%
class GATExpert(torch.nn.Module):
    """2-layer Graph Attention Network."""
    def __init__(self, in_dim, hidden_dim, out_dim, heads=4):
        super().__init__()
        # First layer uses multi-head attention with concatenated outputs
        self.conv1 = GATConv(in_dim, hidden_dim, heads=heads, concat=True)
        # Second layer merges heads into a single output vector
        self.conv2 = GATConv(hidden_dim * heads, out_dim, heads=1, concat=False)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return global_mean_pool(x, batch)          # [B, out_dim]

# %%
class SAGEExpert(torch.nn.Module):
    """2-layer GraphSAGE."""
    def __init__(self, in_dim, hidden_dim, out_dim):
        super().__init__()
        self.conv1 = SAGEConv(in_dim, hidden_dim)
        self.conv2 = SAGEConv(hidden_dim, out_dim)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return global_mean_pool(x, batch)          # [B, out_dim]

# %%
class GINExpert(torch.nn.Module):
    """2-layer Graph Isomorphism Network."""
    def __init__(self, in_dim, hidden_dim, out_dim):
        super().__init__()
        # Each GIN layer wraps an MLP as the aggregation function
        mlp1 = torch.nn.Sequential(torch.nn.Linear(in_dim, hidden_dim), torch.nn.ReLU(),
                                   torch.nn.Linear(hidden_dim, hidden_dim))
        mlp2 = torch.nn.Sequential(torch.nn.Linear(hidden_dim, out_dim), torch.nn.ReLU(),
                                   torch.nn.Linear(out_dim, out_dim))
        self.conv1 = GINConv(mlp1)
        self.conv2 = GINConv(mlp2)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return global_mean_pool(x, batch)          # [B, out_dim]

# %% [markdown]
# ## 3.4 Quantum MoE Layer
#
# `QuantumMoELayer` takes quantum routing weights and runs only the top-k experts per sample. Their outputs are renormalized and averaged to produce the final MoE representation. Running all experts in parallel enables efficient batched GPU computation.

# %%
# ── Quantum MoE Layer ─────────────────────────────────────────────────────────

class QuantumMoELayer(torch.nn.Module):
    """
    Mixture-of-Experts layer driven by quantum routing weights.

    Flow:
      batch_data  +  routing_weights [B, n_experts]
        → top-k selection & renormalization       → sparse weights [B, n_experts]
        → all experts process the graph           → [B, n_experts, out_dim]
        → weighted sum                            → [B, out_dim]
    """

    def __init__(self, experts: list, top_k: int = 2):
        super().__init__()
        assert top_k <= len(experts), "top_k cannot exceed the number of experts"
        self.experts  = torch.nn.ModuleList(experts)
        self.top_k    = top_k
        self.n_experts = len(experts)

    def forward(self, batch_data, routing_weights: torch.Tensor) -> torch.Tensor:
        """
        Args:
            batch_data:      PyG Batch (x, edge_index, batch)
            routing_weights: [B, n_experts] softmax probabilities from QuantumRouter
        Returns:
            out: [B, out_dim]  top-k weighted combination of expert outputs
        """
        # ── 1. Top-k sparse gating ────────────────────────────────────────────
        topk_vals, topk_idx = torch.topk(routing_weights, self.top_k, dim=-1)  # [B, k]
        # Build a sparse weight matrix; zero out non-selected experts
        sparse_weights = torch.zeros_like(routing_weights)
        sparse_weights.scatter_(1, topk_idx, topk_vals)
        # Renormalize so selected weights still sum to 1
        sparse_weights = sparse_weights / sparse_weights.sum(dim=-1, keepdim=True)

        # ── 2. Run every expert on the graph batch ────────────────────────────
        # Stack → [B, n_experts, out_dim]
        expert_outs = torch.stack(
            [expert(batch_data.x, batch_data.edge_index, batch_data.batch)
             for expert in self.experts],
            dim=1
        )

        # ── 3. Weighted sum over experts ──────────────────────────────────────
        # sparse_weights: [B, n_experts] → unsqueeze → [B, n_experts, 1]
        out = (sparse_weights.unsqueeze(-1) * expert_outs).sum(dim=1)  # [B, out_dim]
        return out

# %%
# ── Smoke test ────────────────────────────────────────────────────────────────

# Build expert pool — one per qubit (n_qubits = 8), varied configs for diversity
expert_pool = [
    GCNExpert (feature_dim, config["expert_hidden"],     config["expert_out"]),   # GCN  narrow
    GCNExpert (feature_dim, config["expert_hidden"] * 2, config["expert_out"]),   # GCN  wide
    GATExpert (feature_dim, config["expert_hidden"],     config["expert_out"], heads=4),  # GAT 4-head
    GATExpert (feature_dim, config["expert_hidden"],     config["expert_out"], heads=8),  # GAT 8-head
    SAGEExpert(feature_dim, config["expert_hidden"],     config["expert_out"]),   # SAGE narrow
    SAGEExpert(feature_dim, config["expert_hidden"] * 2, config["expert_out"]),   # SAGE wide
    GINExpert (feature_dim, config["expert_hidden"],     config["expert_out"]),   # GIN  narrow
    GINExpert (feature_dim, config["expert_hidden"] * 2, config["expert_out"]),   # GIN  wide
]
assert len(expert_pool) == config["n_qubits"], "n_experts must equal n_qubits"

moe_layer = QuantumMoELayer(experts=expert_pool, top_k=config["top_k"])

for batch in train_loader:
    g               = summary_module(batch)              # [B, 1372]
    routing_weights = quantum_router(g)                  # [B, 8]
    moe_out         = moe_layer(batch, routing_weights)  # [B, 128]

    print("routing_weights shape: ", routing_weights.shape)
    print("moe_out shape:         ", moe_out.shape)
    print("active experts/sample: ", config["top_k"], "of", config["n_qubits"])
    break
# Out:
# routing_weights shape:  torch.Size([32, 8])
# moe_out shape:          torch.Size([32, 128])
# active experts/sample:  2 of 8

# %% [markdown]
# ## 3.5 Node Updater
#
# `NodeUpdater` feeds the graph-level MoE output back into the node feature space as a residual. Broadcasting the graph vector to every node and projecting it to `node_dim` lets each subsequent iteration operate on richer, MoE-informed features.

# %%
class NodeUpdater(torch.nn.Module):
    """
    Updates node features using the graph-level MoE output.

    The MoE output [B, moe_dim] is broadcast to every node in its graph,
    projected to node_dim, then added as a residual to the current node features.
    LayerNorm stabilizes the mixed representation before the next iteration.

    Flow:
      x [total_nodes, node_dim]  +  moe_out [B, moe_dim]
        → broadcast:  moe_out[batch_idx]       → [total_nodes, moe_dim]
        → project:    Linear(moe_dim→node_dim) → [total_nodes, node_dim]
        → residual:   x + delta
        → LayerNorm                            → [total_nodes, node_dim]
    """

    def __init__(self, moe_dim: int, node_dim: int):
        super().__init__()
        self.proj = torch.nn.Linear(moe_dim, node_dim)
        self.norm = torch.nn.LayerNorm(node_dim)

    def forward(self, x: torch.Tensor, moe_out: torch.Tensor,
                batch_idx: torch.Tensor) -> torch.Tensor:
        """
        Args:
            x:         [total_nodes, node_dim]  current node features
            moe_out:   [B, moe_dim]             graph-level MoE output
            batch_idx: [total_nodes]            graph id for each node (batch_data.batch)
        Returns:
            x_new: [total_nodes, node_dim]
        """
        moe_broadcast = moe_out[batch_idx]          # [total_nodes, moe_dim]
        delta  = self.proj(moe_broadcast)            # [total_nodes, node_dim]
        x_new  = self.norm(x + delta)               # [total_nodes, node_dim]
        return x_new

# %% [markdown]
# ## 3.6 Iterative GQMoE
#
# `IterativeGQMoE` chains the three core modules (GlobalSummary → QuantumRouter → MoE) for `n_iterations` passes. After each pass except the last, `NodeUpdater` refines the node features so the next iteration sees progressively enriched representations.

# %%
class IterativeGQMoE(torch.nn.Module):
    """
    Iterative Quantum Graph Mixture-of-Experts.

    Runs the full pipeline (GlobalSummary → QuantumRouter → MoE) for
    n_iterations passes. After each pass (except the last), NodeUpdater
    injects the graph-level MoE output back into the node features so
    the next iteration operates on refined representations.

    Iteration flow (repeated n_iterations times):
      batch.x [total_nodes, node_dim]
        → GlobalSummary  → g [B, node_dim]
        → QuantumRouter  → routing_weights [B, n_experts]
        → MoE            → moe_out [B, expert_out]
        → NodeUpdater    → batch.x updated  (skipped on final iteration)

    Returns:
      moe_out: [B, expert_out]   output from the final iteration
      batch:   PyG Batch         with batch.x = refined node features from final iteration
    """

    def __init__(
        self,
        summary_module: torch.nn.Module,
        quantum_router: torch.nn.Module,
        moe_layer:      torch.nn.Module,
        node_updater:   torch.nn.Module,
        n_iterations:   int = 3,
    ):
        super().__init__()
        self.summary_module = summary_module
        self.quantum_router = quantum_router
        self.moe_layer      = moe_layer
        self.node_updater   = node_updater
        self.n_iterations   = n_iterations

    def forward(self, batch_data):
        """
        Args:
            batch_data: PyG Batch (x, edge_index, batch, y)
        Returns:
            moe_out: [B, expert_out]  output from the final iteration
            batch:   PyG Batch        batch.x holds the final refined node features
        """
        # Clone to avoid mutating the original batch across DataLoader calls
        batch = batch_data.clone()

        for i in range(self.n_iterations):
            # Stage 1: summarise current node features into a global vector
            g = self.summary_module(batch)                      # [B, node_dim]

            # Stage 2: quantum routing — maps global vector to expert weights
            routing_weights = self.quantum_router(g)            # [B, n_experts]

            # Stage 3: mixture of experts processes the graph
            moe_out = self.moe_layer(batch, routing_weights)    # [B, expert_out]

            # Update node features for the next iteration (skip on last pass)
            if i < self.n_iterations - 1:
                batch.x = self.node_updater(
                    batch.x, moe_out, batch.batch               # [total_nodes, node_dim]
                )

        # Return both the MoE output and the batch carrying refined node features
        return moe_out, batch

# %%
# ── Instantiation ─────────────────────────────────────────────────────────────
node_updater = NodeUpdater(
    moe_dim  = config["expert_out"],   # 128  — MoE output dim
    node_dim = feature_dim,            # 1372 — must match node feature dim
)

iterative_gqmoe = IterativeGQMoE(
    summary_module = summary_module,
    quantum_router = quantum_router,
    moe_layer      = moe_layer,
    node_updater   = node_updater,
    n_iterations   = config["n_iterations"],
)

# ── Smoke test ────────────────────────────────────────────────────────────────
for batch in train_loader:
    original_x_ptr = batch.x.data_ptr()

    moe_out, final_batch = iterative_gqmoe(batch)   # unpack tuple

    print("n_iterations:             ", config["n_iterations"])
    print("moe_out shape:            ", moe_out.shape)        # [32, 128]
    print("final_batch.x shape:      ", final_batch.x.shape) # [total_nodes, 1372]
    assert batch.x.data_ptr() == original_x_ptr, "Original batch.x was mutated!"
    print("original batch.x safe:    True")
    break
# Out:
# n_iterations:              4
# moe_out shape:             torch.Size([32, 128])
# final_batch.x shape:       torch.Size([1568, 16])
# original batch.x safe:    True

# %% [markdown]
# ## 3.7 Full GQMoE Classifier
#
# `GQMoEClassifier` wraps `IterativeGQMoE` and adds a `GlobalAttention` pooling layer followed by a two-layer MLP head. The attention pooling learns to up-weight the most diagnostically relevant nodes before classification.

# %%
class GQMoEClassifier(torch.nn.Module):
    """
    Full GQMoE pipeline ending in diagnostic classification.

    After the iterative loop, the refined node features are pooled with
    GlobalAttention, which learns to assign higher weight to the most
    diagnostically relevant nodes. The pooled vector is then classified
    by a two-layer MLP head.

    Flow:
      batch_data
        → IterativeGQMoE (3 passes)
            → final_batch.x  [total_nodes, node_dim]   refined node features
        → GlobalAttention pooling
            gate: Linear(node_dim → clf_hidden → 1)
            → attn_g  [B, node_dim]                    attention-weighted graph vector
        → MLP head
            Linear(node_dim → clf_hidden) → ReLU → Dropout → Linear(clf_hidden → n_classes)
            → logits  [B, n_classes]
    """

    def __init__(
        self,
        iterative_gqmoe: torch.nn.Module,
        node_dim:   int,
        n_classes:  int,
        clf_hidden: int = 256,
        dropout:    float = 0.3,
    ):
        super().__init__()
        self.iterative_gqmoe = iterative_gqmoe

        # gate_nn scores each node → softmax over nodes in same graph → weighted sum
        gate_nn = torch.nn.Sequential(
            torch.nn.Linear(node_dim, clf_hidden),
            torch.nn.ReLU(),
            torch.nn.Linear(clf_hidden, 1),
        )
        self.attn_pool = GlobalAttention(gate_nn=gate_nn)

        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(node_dim, clf_hidden),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout),
            torch.nn.Linear(clf_hidden, n_classes),
        )

    def forward(self, batch_data) -> torch.Tensor:
        _, final_batch = self.iterative_gqmoe(batch_data)
        attn_g = self.attn_pool(final_batch.x, final_batch.batch)  # [B, node_dim]
        logits = self.classifier(attn_g)                            # [B, n_classes]
        return logits

# %%
# ── Instantiation + Smoke test ────────────────────────────────────────────────
model = GQMoEClassifier(
    iterative_gqmoe = iterative_gqmoe,
    node_dim        = feature_dim,
    n_classes       = config["n_classes"],
    clf_hidden      = config["clf_hidden"],
    dropout         = 0.3,
)

for batch in train_loader:
    logits = model(batch)                          # [B, 2]
    preds  = logits.argmax(dim=-1)                 # [B]

    print("logits shape:  ", logits.shape)
    print("preds sample:  ", preds[:8].tolist())
    print("labels sample: ", batch.y[:8].squeeze().tolist())

    logits.sum().backward()
    assert model.attn_pool.gate_nn[0].weight.grad is not None, "attn_pool has no gradient"
    print("gradients flow: True")
    break
# Out:
# logits shape:   torch.Size([32, 4])
# preds sample:   [1, 2, 3, 3, 1, 3, 3, 3]
# labels sample:  [0, 0, 3, 1, 0, 3, 0, 1]
# /tmp/ipykernel_811/2356442293.py:39: UserWarning: 'nn.glob.GlobalAttention' is deprecated, use 'nn.aggr.AttentionalAggregation' instead
#   self.attn_pool = GlobalAttention(gate_nn=gate_nn)
# gradients flow: True

# %%
# Print a per-module parameter breakdown to understand model size
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"{'Module':<60} {'Parameters':>12}")
print("-" * 74)
for name, module in model.named_modules():
    params = sum(p.numel() for p in module.parameters(recurse=False))
    if params > 0:
        print(f"{name:<60} {params:>12,}")
print("-" * 74)
print(f"{'Total parameters':<60} {total_params:>12,}")
print(f"{'Trainable parameters':<60} {trainable_params:>12,}")
print(f"{'Non-trainable parameters':<60} {total_params - trainable_params:>12,}")
# Out:
# Module                                                         Parameters
# --------------------------------------------------------------------------
# iterative_gqmoe.quantum_router.encoder.0                              136
# iterative_gqmoe.quantum_router.vqc                                     16
# iterative_gqmoe.moe_layer.experts.0.conv1                              64
# iterative_gqmoe.moe_layer.experts.0.conv1.lin                       1,024
# iterative_gqmoe.moe_layer.experts.0.conv2                             128
# iterative_gqmoe.moe_layer.experts.0.conv2.lin                       8,192
# iterative_gqmoe.moe_layer.experts.1.conv1                             128
# iterative_gqmoe.moe_layer.experts.1.conv1.lin                       2,048
# iterative_gqmoe.moe_layer.experts.1.conv2                             128
# iterative_gqmoe.moe_layer.experts.1.conv2.lin                      16,384
# iterative_gqmoe.moe_layer.experts.2.conv1                             768
# iterative_gqmoe.moe_layer.experts.2.conv1.lin                       4,096
# iterative_gqmoe.moe_layer.experts.2.conv2                             384
# iterative_gqmoe.moe_layer.experts.2.conv2.lin                      32,768
# iterative_gqmoe.moe_layer.experts.3.conv1                           1,536
# iterative_gqmoe.moe_layer.experts.3.conv1.lin                       8,192
# iterative_gqmoe.moe_layer.experts.3.conv2                             384
# iterative_gqmoe.moe_layer.experts.3.conv2.lin                      65,536
# iterative_gqmoe.moe_layer.experts.4.conv1.lin_l                     1,088
# iterative_gqmoe.moe_layer.experts.4.conv1.lin_r                     1,024
# iterative_gqmoe.moe_layer.experts.4.conv2.lin_l                     8,320
# iterative_gqmoe.moe_layer.experts.4.conv2.lin_r                     8,192
# iterative_gqmoe.moe_layer.experts.5.conv1.lin_l                     2,176
# iterative_gqmoe.moe_layer.experts.5.conv1.lin_r                     2,048
# iterative_gqmoe.moe_layer.experts.5.conv2.lin_l                    16,512
# iterative_gqmoe.moe_layer.experts.5.conv2.lin_r                    16,384
# iterative_gqmoe.moe_layer.experts.6.conv1.nn.0                      1,088
# iterative_gqmoe.moe_layer.experts.6.conv1.nn.2                      4,160
# iterative_gqmoe.moe_layer.experts.6.conv2.nn.0                      8,320
# iterative_gqmoe.moe_layer.experts.6.conv2.nn.2                     16,512
# iterative_gqmoe.moe_layer.experts.7.conv1.nn.0                      2,176
# iterative_gqmoe.moe_layer.experts.7.conv1.nn.2                     16,512
# iterative_gqmoe.moe_layer.experts.7.conv2.nn.0                     16,512
# iterative_gqmoe.moe_layer.experts.7.conv2.nn.2                     16,512
# iterative_gqmoe.node_updater.proj                                   2,064
# iterative_gqmoe.node_updater.norm                                      32
# attn_pool.gate_nn.0                                                 4,352
# attn_pool.gate_nn.2                                                   257
# classifier.0                                                        4,352
# classifier.3                                                        1,028
# --------------------------------------------------------------------------
# Total parameters                                                  291,533
# Trainable parameters                                              291,533
# Non-trainable parameters                                                0

# %% [markdown]
# # Part 4: Training
#
# This section sets up Weights & Biases logging, defines the per-epoch training and evaluation helpers, and runs the full training loop. The loop uses linear LR warmup followed by cosine annealing, saves checkpoints to Drive every epoch, and supports resuming from any saved checkpoint.

# %%
import wandb

# Log in to Weights & Biases for experiment tracking
wandb.login(key="<YOUR_KEY")
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: peijingl1221 (peijingl1221-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
def train_one_epoch(model, loader, optimizer, criterion, device):
    """Run one full pass over the training set and return loss and accuracy."""
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for batch in loader:
        batch  = batch.to(device)
        optimizer.zero_grad()
        logits = model(batch)
        labels = batch.y.squeeze()
        loss   = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        # Accumulate weighted loss and correct predictions for the epoch average
        total_loss += loss.item() * batch.num_graphs
        correct    += (logits.argmax(dim=-1) == labels).sum().item()
        total      += batch.num_graphs
    return total_loss / total, correct / total

# %%
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    """Evaluate the model on a given loader (validation or test) without gradients."""
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_probs, all_labs = [], []
    for batch in loader:
        batch  = batch.to(device)
        logits = model(batch)
        labels = batch.y.squeeze()
        loss   = criterion(logits, labels)
        total_loss += loss.item() * batch.num_graphs
        correct    += (logits.argmax(dim=-1) == labels).sum().item()
        total      += batch.num_graphs
        all_probs.append(torch.softmax(logits, dim=-1).cpu())
        all_labs.append(labels.cpu())
    all_probs = torch.cat(all_probs, dim=0).numpy()
    all_labs  = torch.cat(all_labs,  dim=0).numpy()
    try:
        auc = roc_auc_score(all_labs, all_probs, multi_class="ovr", average="macro")
    except ValueError:
        auc = float("nan")
    return total_loss / total, correct / total, auc

# %%
def train(model, train_loader, val_loader, config):
    """
    Train GQMoEClassifier with W&B logging, full resume support,
    and linear LR warmup followed by cosine annealing decay.
    Checkpoints and history are saved to Google Drive.
    """
    device    = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model     = model.to(device)
    criterion = torch.nn.CrossEntropyLoss()

    # Initialize optimizer with the target_lr. This will be the base_lr that LinearLR scales.
    target_lr = config["lr"]
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr           = target_lr,
        weight_decay = config["weight_decay"],
    )

    # Checkpoints and history go to Drive so they survive kernel restarts
    best_ckpt    = f"{DRIVE_DIR}/best_model.pt"
    last_ckpt    = f"{DRIVE_DIR}/checkpoint.pt"
    history_path = f"{DRIVE_DIR}/history.json"

    # ── Initial state variables ────────────────────────────────────────────────
    start_epoch  = 1
    best_val_auc = 0.0
    wandb_run_id = None
    history      = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": [], "train_auc": [], "val_auc": [], "lr": []}
    warmup_epochs_to_run = config.get("warmup_epochs", 5)

    # Determine if resuming from the best model is requested and possible
    should_resume_from_best = config.get("resume_ckpt") is not None and os.path.exists(best_ckpt)

    if should_resume_from_best:
        print(f"Resuming training from '{best_ckpt}' (best validation AUC).")
        model.load_state_dict(torch.load(best_ckpt, map_location=device))

        # Load history to find when best model was saved and its AUC
        if os.path.exists(history_path):
            with open(history_path) as f:
                loaded_history = json.load(f)
            history = loaded_history # Use this history for logging

            # Find the epoch with the highest validation AUC
            if loaded_history["val_auc"]:
                best_epoch_idx = np.argmax(loaded_history["val_auc"])
                start_epoch = best_epoch_idx + 1 # 0-indexed history, so +1 for epoch number
                best_val_auc = loaded_history["val_auc"][best_epoch_idx]
                print(f"  (Best model achieved AUC {best_val_auc:.4f} at epoch {best_epoch_idx + 1}).")
            else:
                print("  Warning: No validation AUC history found. Cannot determine best epoch. Starting from epoch 1.")
                start_epoch = 1
        else:
            print(f"  Warning: History file '{history_path}' not found. Cannot determine best epoch. Starting from epoch 1.")
            start_epoch = 1

        # For this case, optimizer's LR is already set to target_lr initially
        print(f"Starting new training phase from epoch {start_epoch} with LR warmup from 0.00e+00 to {target_lr:.2e}.")
        wandb_run_id = None # Reset W&B run ID to force a new run for this new training phase

    else:
        # Fresh training run
        # For this case, optimizer's LR is already set to target_lr initially
        print(f"Starting fresh training run with LR warmup from 0.00e+00 to {target_lr:.2e}.")
        start_epoch = 1 # Ensure start_epoch is 1 for a fresh run


    # ── Rebuild scheduler (always linear warmup from 0 to target_lr, then cosine annealing) ───────────────────
    # Calculate remaining total epochs for this specific run relative to start_epoch
    epochs_for_scheduler = config["epochs"] - (start_epoch - 1)
    # Ensure warmup doesn't go beyond available epochs in this run
    effective_warmup_epochs = min(warmup_epochs_to_run, epochs_for_scheduler)
    effective_cosine_epochs = max(0, epochs_for_scheduler - effective_warmup_epochs)

    warmup_scheduler = torch.optim.lr_scheduler.LinearLR(
        optimizer, start_factor=1e-6, end_factor=1.0, total_iters=effective_warmup_epochs,
    )
    cosine_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=effective_cosine_epochs
    )
    scheduler = torch.optim.lr_scheduler.SequentialLR(
        optimizer, schedulers=[warmup_scheduler, cosine_scheduler], milestones=[effective_warmup_epochs],
    )
    print(f"Scheduler: {effective_warmup_epochs} warmup epochs, then {effective_cosine_epochs} cosine annealing epochs.")


    # ── W&B init ─────────────────────────────────
    wandb.init(
        project=config["wandb_project"], name=config["wandb_run"],
        id=wandb_run_id, resume="allow", config=config,
    )
    wandb.watch(model, log="gradients", log_freq=10)

    for epoch in range(start_epoch, config["epochs"] + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss,   val_acc,  val_auc  = evaluate(model, val_loader, criterion, device)
        scheduler.step()
        current_lr = scheduler.get_last_lr()[0]

        # Append to history
        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)
        history["val_auc"].append(val_auc)
        history["lr"].append(current_lr)

        wandb.log(
            {
            "epoch": epoch, "train/loss": train_loss, "train/acc": train_acc,
            "val/loss": val_loss, "val/acc": val_acc, "val/auc": val_auc, "lr": current_lr,
        })

        # The phase determination needs to be relative to the current run's warmup
        phase = "warmup" if (epoch - start_epoch + 1) <= warmup_epochs_to_run else "cosine"
        print(
            f"Epoch {epoch:03d}/{config['epochs']} [{phase}] | "
            f"lr {current_lr:.2e} | "
            f"train loss {train_loss:.4f}  acc {train_acc:.4f} | "
            f"val loss {val_loss:.4f}  acc {val_acc:.4f}  auc {val_auc:.4f}"
        )

        # Save checkpoint and history to Drive every epoch
        torch.save(
            {
            "epoch": epoch, "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            # Do NOT save scheduler state as it's rebuilt on resume
            "best_val_auc": best_val_auc, "wandb_run_id": wandb.run.id,
        }, last_ckpt)
        with open(history_path, "w") as f:
            json.dump(history, f)

        if val_auc > best_val_auc:
            best_val_auc = val_auc
            torch.save(model.state_dict(), best_ckpt)
            wandb.save(best_ckpt)
            print(f"  ♦ new best val auc: {best_val_auc:.4f}  →  saved to Drive")

    best_val_acc = max(history["val_acc"]) if history["val_acc"] else float("nan")
    wandb.log({"best_val_acc": best_val_acc, "best_val_auc": best_val_auc})
    wandb.finish()
    print(f"\nTraining complete. Best val auc: {best_val_auc:.4f}")
    print(f"Checkpoints saved in: {DRIVE_DIR}")
    return model, history

# %%
# ── Run training ──────────────────────────────────────────────────────────────
model, history = train(model, train_loader, val_loader, config)
# Out:
# Resuming training from '/content/drive/MyDrive/GQMoE/best_model.pt' (best validation AUC).
#   (Best model achieved AUC 0.9097 at epoch 294).
# Starting new training phase from epoch 294 with LR warmup from 0.00e+00 to 1.00e-03.
# Scheduler: 2 warmup epochs, then 105 cosine annealing epochs.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260419_140920-bbtq95bi</code>
# Syncing run <strong><a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE/runs/bbtq95bi' target="_blank">gqmoe-octmnist-v1</a></strong> to <a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE' target="_blank">https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE</a>
#  View run at <a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE/runs/bbtq95bi' target="_blank">https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE/runs/bbtq95bi</a>
# Epoch 294/400 [warmup] | lr 5.00e-04 | train loss 0.5540  acc 0.8021 | val loss 0.5420  acc 0.8059  auc 0.9097
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
#   ♦ new best val auc: 0.9097  →  saved to Drive
# Epoch 295/400 [warmup] | lr 1.00e-03 | train loss 0.5620  acc 0.8005 | val loss 0.5291  acc 0.8128  auc 0.9114
#   ♦ new best val auc: 0.9114  →  saved to Drive
# Epoch 296/400 [cosine] | lr 1.00e-03 | train loss 0.5664  acc 0.7999 | val loss 0.5490  acc 0.8053  auc 0.9040
# Epoch 297/400 [cosine] | lr 9.99e-04 | train loss 0.5539  acc 0.8039 | val loss 0.5447  acc 0.8088  auc 0.9048
# Epoch 298/400 [cosine] | lr 9.98e-04 | train loss 0.5426  acc 0.8088 | val loss 0.5352  acc 0.8117  auc 0.9055
# Epoch 299/400 [cosine] | lr 9.96e-04 | train loss 0.5349  acc 0.8100 | val loss 0.5194  acc 0.8158  auc 0.9126
#   ♦ new best val auc: 0.9126  →  saved to Drive
# Epoch 300/400 [cosine] | lr 9.94e-04 | train loss 0.5269  acc 0.8144 | val loss 0.5149  acc 0.8163  auc 0.9136
#   ♦ new best val auc: 0.9136  →  saved to Drive
# Epoch 301/400 [cosine] | lr 9.92e-04 | train loss 0.5214  acc 0.8155 | val loss 0.5143  acc 0.8179  auc 0.9145
#   ♦ new best val auc: 0.9145  →  saved to Drive
# Epoch 302/400 [cosine] | lr 9.89e-04 | train loss 0.5187  acc 0.8163 | val loss 0.5106  acc 0.8180  auc 0.9124
# Epoch 303/400 [cosine] | lr 9.86e-04 | train loss 0.5142  acc 0.8170 | val loss 0.5323  acc 0.8116  auc 0.9136
# Epoch 304/400 [cosine] | lr 9.82e-04 | train loss 0.5095  acc 0.8187 | val loss 0.5141  acc 0.8158  auc 0.9168
#   ♦ new best val auc: 0.9168  →  saved to Drive
# Epoch 305/400 [cosine] | lr 9.78e-04 | train loss 0.5055  acc 0.8210 | val loss 0.5132  acc 0.8161  auc 0.9173
#   ♦ new best val auc: 0.9173  →  saved to Drive
# Epoch 306/400 [cosine] | lr 9.73e-04 | train loss 0.5017  acc 0.8230 | val loss 0.5046  acc 0.8218  auc 0.9156
# Epoch 307/400 [cosine] | lr 9.68e-04 | train loss 0.4993  acc 0.8233 | val loss 0.5058  acc 0.8244  auc 0.9180
#   ♦ new best val auc: 0.9180  →  saved to Drive
# Epoch 308/400 [cosine] | lr 9.63e-04 | train loss 0.4957  acc 0.8231 | val loss 0.4980  acc 0.8241  auc 0.9184
#   ♦ new best val auc: 0.9184  →  saved to Drive
# Epoch 309/400 [cosine] | lr 9.57e-04 | train loss 0.4939  acc 0.8253 | val loss 0.4971  acc 0.8272  auc 0.9180
# Epoch 310/400 [cosine] | lr 9.50e-04 | train loss 0.4922  acc 0.8264 | val loss 0.4880  acc 0.8265  auc 0.9215
#   ♦ new best val auc: 0.9215  →  saved to Drive
# Epoch 311/400 [cosine] | lr 9.44e-04 | train loss 0.4900  acc 0.8261 | val loss 0.5102  acc 0.8190  auc 0.9161
# Epoch 312/400 [cosine] | lr 9.37e-04 | train loss 0.4873  acc 0.8285 | val loss 0.5351  acc 0.8117  auc 0.9129
# Epoch 313/400 [cosine] | lr 9.29e-04 | train loss 0.4850  acc 0.8286 | val loss 0.5232  acc 0.8088  auc 0.9183
# Epoch 314/400 [cosine] | lr 9.21e-04 | train loss 0.4839  acc 0.8294 | val loss 0.5173  acc 0.8191  auc 0.9163
# Epoch 315/400 [cosine] | lr 9.13e-04 | train loss 0.4811  acc 0.8293 | val loss 0.5308  acc 0.8093  auc 0.9170
# Epoch 316/400 [cosine] | lr 9.05e-04 | train loss 0.4776  acc 0.8306 | val loss 0.4959  acc 0.8231  auc 0.9220
#   ♦ new best val auc: 0.9220  →  saved to Drive
# Epoch 317/400 [cosine] | lr 8.96e-04 | train loss 0.4780  acc 0.8302 | val loss 0.4919  acc 0.8257  auc 0.9205
# Epoch 318/400 [cosine] | lr 8.86e-04 | train loss 0.4757  acc 0.8304 | val loss 0.5283  acc 0.8132  auc 0.9136
# Epoch 319/400 [cosine] | lr 8.77e-04 | train loss 0.4727  acc 0.8326 | val loss 0.4843  acc 0.8273  auc 0.9206
# Epoch 320/400 [cosine] | lr 8.67e-04 | train loss 0.4694  acc 0.8339 | val loss 0.4837  acc 0.8269  auc 0.9227
#   ♦ new best val auc: 0.9227  →  saved to Drive
# Epoch 321/400 [cosine] | lr 8.56e-04 | train loss 0.4691  acc 0.8332 | val loss 0.4770  acc 0.8313  auc 0.9227
# Epoch 322/400 [cosine] | lr 8.46e-04 | train loss 0.4673  acc 0.8340 | val loss 0.4817  acc 0.8269  auc 0.9241
#   ♦ new best val auc: 0.9241  →  saved to Drive
# Epoch 323/400 [cosine] | lr 8.35e-04 | train loss 0.4647  acc 0.8352 | val loss 0.4802  acc 0.8293  auc 0.9244
#   ♦ new best val auc: 0.9244  →  saved to Drive
# Epoch 324/400 [cosine] | lr 8.23e-04 | train loss 0.4619  acc 0.8366 | val loss 0.5119  acc 0.8218  auc 0.9196
# Epoch 325/400 [cosine] | lr 8.12e-04 | train loss 0.4593  acc 0.8377 | val loss 0.4713  acc 0.8324  auc 0.9264
#   ♦ new best val auc: 0.9264  →  saved to Drive
# Epoch 326/400 [cosine] | lr 8.00e-04 | train loss 0.4581  acc 0.8371 | val loss 0.4844  acc 0.8274  auc 0.9216
# Epoch 327/400 [cosine] | lr 7.88e-04 | train loss 0.4573  acc 0.8378 | val loss 0.4897  acc 0.8255  auc 0.9221
# Epoch 328/400 [cosine] | lr 7.75e-04 | train loss 0.4542  acc 0.8392 | val loss 0.4813  acc 0.8277  auc 0.9221
# Epoch 329/400 [cosine] | lr 7.63e-04 | train loss 0.4532  acc 0.8401 | val loss 0.4878  acc 0.8252  auc 0.9247
# Epoch 330/400 [cosine] | lr 7.50e-04 | train loss 0.4513  acc 0.8398 | val loss 0.4976  acc 0.8212  auc 0.9237
# Epoch 331/400 [cosine] | lr 7.37e-04 | train loss 0.4495  acc 0.8407 | val loss 0.4794  acc 0.8299  auc 0.9233
# Epoch 332/400 [cosine] | lr 7.24e-04 | train loss 0.4469  acc 0.8420 | val loss 0.4701  acc 0.8339  auc 0.9260
# Epoch 333/400 [cosine] | lr 7.10e-04 | train loss 0.4464  acc 0.8420 | val loss 0.4709  acc 0.8338  auc 0.9253
# Epoch 334/400 [cosine] | lr 6.97e-04 | train loss 0.4451  acc 0.8418 | val loss 0.4640  acc 0.8361  auc 0.9274
#   ♦ new best val auc: 0.9274  →  saved to Drive
# Epoch 335/400 [cosine] | lr 6.83e-04 | train loss 0.4435  acc 0.8416 | val loss 0.4770  acc 0.8306  auc 0.9251
# Epoch 336/400 [cosine] | lr 6.69e-04 | train loss 0.4415  acc 0.8426 | val loss 0.4764  acc 0.8321  auc 0.9249
# Epoch 337/400 [cosine] | lr 6.55e-04 | train loss 0.4384  acc 0.8442 | val loss 0.4650  acc 0.8377  auc 0.9264
# Epoch 338/400 [cosine] | lr 6.40e-04 | train loss 0.4356  acc 0.8458 | val loss 0.4690  acc 0.8349  auc 0.9272
# Epoch 339/400 [cosine] | lr 6.26e-04 | train loss 0.4337  acc 0.8458 | val loss 0.4759  acc 0.8343  auc 0.9258
# Epoch 340/400 [cosine] | lr 6.11e-04 | train loss 0.4329  acc 0.8460 | val loss 0.4615  acc 0.8395  auc 0.9280
#   ♦ new best val auc: 0.9280  →  saved to Drive
# Epoch 341/400 [cosine] | lr 5.97e-04 | train loss 0.4305  acc 0.8472 | val loss 0.4623  acc 0.8367  auc 0.9286
#   ♦ new best val auc: 0.9286  →  saved to Drive
# Epoch 342/400 [cosine] | lr 5.82e-04 | train loss 0.4289  acc 0.8480 | val loss 0.4654  acc 0.8348  auc 0.9267
# Epoch 343/400 [cosine] | lr 5.67e-04 | train loss 0.4261  acc 0.8485 | val loss 0.4731  acc 0.8275  auc 0.9280
# Epoch 344/400 [cosine] | lr 5.52e-04 | train loss 0.4261  acc 0.8479 | val loss 0.4679  acc 0.8334  auc 0.9275
# Epoch 345/400 [cosine] | lr 5.37e-04 | train loss 0.4234  acc 0.8505 | val loss 0.4632  acc 0.8359  auc 0.9271
# Epoch 346/400 [cosine] | lr 5.22e-04 | train loss 0.4213  acc 0.8504 | val loss 0.4670  acc 0.8357  auc 0.9268
# Epoch 347/400 [cosine] | lr 5.07e-04 | train loss 0.4221  acc 0.8499 | val loss 0.4692  acc 0.8336  auc 0.9272
# Epoch 348/400 [cosine] | lr 4.93e-04 | train loss 0.4178  acc 0.8527 | val loss 0.4602  acc 0.8390  auc 0.9294
#   ♦ new best val auc: 0.9294  →  saved to Drive
# Epoch 349/400 [cosine] | lr 4.78e-04 | train loss 0.4161  acc 0.8518 | val loss 0.4597  acc 0.8393  auc 0.9286
# Epoch 350/400 [cosine] | lr 4.63e-04 | train loss 0.4150  acc 0.8532 | val loss 0.4638  acc 0.8395  auc 0.9294
# Epoch 351/400 [cosine] | lr 4.48e-04 | train loss 0.4123  acc 0.8525 | val loss 0.4692  acc 0.8374  auc 0.9259
# Epoch 352/400 [cosine] | lr 4.33e-04 | train loss 0.4102  acc 0.8548 | val loss 0.4643  acc 0.8362  auc 0.9270
# Epoch 353/400 [cosine] | lr 4.18e-04 | train loss 0.4104  acc 0.8545 | val loss 0.4625  acc 0.8360  auc 0.9290
# Epoch 354/400 [cosine] | lr 4.03e-04 | train loss 0.4071  acc 0.8556 | val loss 0.4673  acc 0.8379  auc 0.9267
# Epoch 355/400 [cosine] | lr 3.89e-04 | train loss 0.4064  acc 0.8563 | val loss 0.4564  acc 0.8421  auc 0.9292
# Epoch 356/400 [cosine] | lr 3.74e-04 | train loss 0.4018  acc 0.8574 | val loss 0.4657  acc 0.8389  auc 0.9280
# Epoch 357/400 [cosine] | lr 3.60e-04 | train loss 0.4018  acc 0.8575 | val loss 0.4648  acc 0.8399  auc 0.9276
# Epoch 358/400 [cosine] | lr 3.45e-04 | train loss 0.4012  acc 0.8578 | val loss 0.4822  acc 0.8272  auc 0.9268
# Epoch 359/400 [cosine] | lr 3.31e-04 | train loss 0.3993  acc 0.8589 | val loss 0.4558  acc 0.8404  auc 0.9301
#   ♦ new best val auc: 0.9301  →  saved to Drive
# Epoch 360/400 [cosine] | lr 3.17e-04 | train loss 0.3965  acc 0.8593 | val loss 0.4576  acc 0.8406  auc 0.9298
# Epoch 361/400 [cosine] | lr 3.03e-04 | train loss 0.3956  acc 0.8598 | val loss 0.4730  acc 0.8345  auc 0.9274
# Epoch 362/400 [cosine] | lr 2.90e-04 | train loss 0.3932  acc 0.8606 | val loss 0.4582  acc 0.8380  auc 0.9291
# Epoch 363/400 [cosine] | lr 2.76e-04 | train loss 0.3932  acc 0.8605 | val loss 0.4606  acc 0.8368  auc 0.9300
# Epoch 364/400 [cosine] | lr 2.63e-04 | train loss 0.3917  acc 0.8609 | val loss 0.4570  acc 0.8393  auc 0.9292
# Epoch 365/400 [cosine] | lr 2.50e-04 | train loss 0.3896  acc 0.8620 | val loss 0.4630  acc 0.8347  auc 0.9290
# Epoch 366/400 [cosine] | lr 2.37e-04 | train loss 0.3876  acc 0.8624 | val loss 0.4665  acc 0.8407  auc 0.9289
# Epoch 367/400 [cosine] | lr 2.25e-04 | train loss 0.3875  acc 0.8628 | val loss 0.4666  acc 0.8383  auc 0.9275
# Epoch 368/400 [cosine] | lr 2.12e-04 | train loss 0.3932  acc 0.8601 | val loss 0.4727  acc 0.8348  auc 0.9261
# Epoch 369/400 [cosine] | lr 2.00e-04 | train loss 0.3931  acc 0.8598 | val loss 0.4730  acc 0.8334  auc 0.9272
# Epoch 370/400 [cosine] | lr 1.88e-04 | train loss 0.3924  acc 0.8610 | val loss 0.4658  acc 0.8363  auc 0.9275
# Epoch 371/400 [cosine] | lr 1.77e-04 | train loss 0.3898  acc 0.8613 | val loss 0.4682  acc 0.8360  auc 0.9282
# Epoch 372/400 [cosine] | lr 1.65e-04 | train loss 0.3887  acc 0.8626 | val loss 0.4684  acc 0.8386  auc 0.9280
# Epoch 373/400 [cosine] | lr 1.54e-04 | train loss 0.3892  acc 0.8620 | val loss 0.4681  acc 0.8367  auc 0.9277
# Epoch 374/400 [cosine] | lr 1.44e-04 | train loss 0.3891  acc 0.8629 | val loss 0.4704  acc 0.8368  auc 0.9285
# Epoch 375/400 [cosine] | lr 1.33e-04 | train loss 0.3867  acc 0.8627 | val loss 0.4714  acc 0.8377  auc 0.9281
# Epoch 376/400 [cosine] | lr 1.23e-04 | train loss 0.3845  acc 0.8631 | val loss 0.4663  acc 0.8380  auc 0.9286
# Epoch 377/400 [cosine] | lr 1.14e-04 | train loss 0.3834  acc 0.8643 | val loss 0.4705  acc 0.8371  auc 0.9280
# Epoch 378/400 [cosine] | lr 1.04e-04 | train loss 0.3810  acc 0.8647 | val loss 0.4673  acc 0.8399  auc 0.9284
# Epoch 379/400 [cosine] | lr 9.55e-05 | train loss 0.3810  acc 0.8644 | val loss 0.4675  acc 0.8374  auc 0.9281
# Epoch 380/400 [cosine] | lr 8.69e-05 | train loss 0.3786  acc 0.8658 | val loss 0.4750  acc 0.8357  auc 0.9272
# Epoch 381/400 [cosine] | lr 7.86e-05 | train loss 0.3777  acc 0.8662 | val loss 0.4700  acc 0.8381  auc 0.9278
# Epoch 382/400 [cosine] | lr 7.08e-05 | train loss 0.3771  acc 0.8665 | val loss 0.4673  acc 0.8374  auc 0.9288
# Epoch 383/400 [cosine] | lr 6.33e-05 | train loss 0.3757  acc 0.8677 | val loss 0.4678  acc 0.8409  auc 0.9278
# Epoch 384/400 [cosine] | lr 5.62e-05 | train loss 0.3750  acc 0.8676 | val loss 0.4677  acc 0.8387  auc 0.9285
# Epoch 385/400 [cosine] | lr 4.95e-05 | train loss 0.3745  acc 0.8670 | val loss 0.4656  acc 0.8403  auc 0.9290
# Epoch 386/400 [cosine] | lr 4.32e-05 | train loss 0.3736  acc 0.8685 | val loss 0.4659  acc 0.8392  auc 0.9293
# Epoch 387/400 [cosine] | lr 3.73e-05 | train loss 0.3723  acc 0.8678 | val loss 0.4692  acc 0.8393  auc 0.9282
# Epoch 388/400 [cosine] | lr 3.19e-05 | train loss 0.3719  acc 0.8681 | val loss 0.4654  acc 0.8407  auc 0.9290
# Epoch 389/400 [cosine] | lr 2.68e-05 | train loss 0.3718  acc 0.8680 | val loss 0.4657  acc 0.8394  auc 0.9291
# Epoch 390/400 [cosine] | lr 2.22e-05 | train loss 0.3703  acc 0.8692 | val loss 0.4673  acc 0.8410  auc 0.9287
# Epoch 391/400 [cosine] | lr 1.80e-05 | train loss 0.3702  acc 0.8687 | val loss 0.4697  acc 0.8386  auc 0.9282
# Epoch 392/400 [cosine] | lr 1.43e-05 | train loss 0.3691  acc 0.8695 | val loss 0.4684  acc 0.8391  auc 0.9286
# Epoch 393/400 [cosine] | lr 1.09e-05 | train loss 0.3686  acc 0.8701 | val loss 0.4676  acc 0.8395  auc 0.9287
# Epoch 394/400 [cosine] | lr 8.04e-06 | train loss 0.3679  acc 0.8700 | val loss 0.4679  acc 0.8399  auc 0.9286
# Epoch 395/400 [cosine] | lr 5.58e-06 | train loss 0.3682  acc 0.8696 | val loss 0.4673  acc 0.8392  auc 0.9288
# Epoch 396/400 [cosine] | lr 3.58e-06 | train loss 0.3678  acc 0.8696 | val loss 0.4679  acc 0.8385  auc 0.9287
# Epoch 397/400 [cosine] | lr 2.01e-06 | train loss 0.3668  acc 0.8694 | val loss 0.4677  acc 0.8403  auc 0.9286
# Epoch 398/400 [cosine] | lr 8.95e-07 | train loss 0.3661  acc 0.8706 | val loss 0.4677  acc 0.8391  auc 0.9286
# Epoch 399/400 [cosine] | lr 2.24e-07 | train loss 0.3667  acc 0.8699 | val loss 0.4677  acc 0.8395  auc 0.9286
# Epoch 400/400 [cosine] | lr 0.00e+00 | train loss 0.3663  acc 0.8701 | val loss 0.4677  acc 0.8395  auc 0.9286
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁</td></tr><tr><td>best_val_auc</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>lr</td><td>▅█████████▇▇▇▇▇▆▆▆▆▅▅▅▅▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>train/acc</td><td>▁▁▁▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>train/loss</td><td>██▇▇▇▇▆▆▆▆▅▅▅▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/acc</td><td>▂▁▃▃▃▅▅▅▄▂▅▆▅▅▅▇▇▆▇▇█▇▇▇█▇▇█▇█▆▇▇▇▇█████</td></tr><tr><td>val/auc</td><td>▃▃▁▁▃▅▅▆▄▃▄▄▆▅▆▆▇▆▇▇█▇▇███▇▇▇██▇████████</td></tr><tr><td>val/loss</td><td>▇█▆▆▅▄▅▇▇▇▅▃▃▃▄▂▂▂▃▂▂▂▂▂▂▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>0.84213</td></tr><tr><td>best_val_auc</td><td>0.93015</td></tr><tr><td>epoch</td><td>400</td></tr><tr><td>lr</td><td>0</td></tr><tr><td>train/acc</td><td>0.87007</td></tr><tr><td>train/loss</td><td>0.36634</td></tr><tr><td>val/acc</td><td>0.83955</td></tr><tr><td>val/auc</td><td>0.92863</td></tr><tr><td>val/loss</td><td>0.46772</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gqmoe-octmnist-v1</strong> at: <a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE/runs/bbtq95bi' target="_blank">https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE/runs/bbtq95bi</a><br> View project at: <a href='https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE' target="_blank">https://wandb.ai/peijingl1221-carnegie-mellon-university/GQMoE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260419_140920-bbtq95bi/logs</code>
# Training complete. Best val auc: 0.9301
# Checkpoints saved in: /content/drive/MyDrive/GQMoE

# %%
# ── Test Evaluation (best checkpoint) ────────────────────────────────────────
device    = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_ckpt = f"{DRIVE_DIR}/best_model.pt"

model.load_state_dict(torch.load(best_ckpt, map_location=device))
model.eval().to(device)

all_preds, all_labels, all_probs = [], [], []
with torch.no_grad():
    for batch in test_loader:
        batch  = batch.to(device)
        logits = model(batch)
        probs  = torch.softmax(logits, dim=-1).cpu()
        preds  = logits.argmax(dim=-1).cpu().tolist()
        labs   = batch.y.squeeze().cpu().tolist()
        all_preds.extend(preds)
        all_labels.extend(labs if isinstance(labs, list) else [labs])
        all_probs.append(probs)

all_probs = torch.cat(all_probs, dim=0).numpy()
test_acc  = (np.array(all_preds) == np.array(all_labels)).mean() * 100
try:
    test_auc = roc_auc_score(all_labels, all_probs, multi_class="ovr", average="macro")
except ValueError:
    test_auc = float("nan")

print(f"Test Accuracy : {test_acc:.2f}%")
print(f"Test Macro AUC: {test_auc:.4f}")
print()
print(classification_report(
    all_labels, all_preds,
    target_names=[f"Class {i}" for i in range(config["n_classes"])]
))
# Out:
# Test Accuracy : 63.80%
# Test Macro AUC: 0.9211
#
#               precision    recall  f1-score   support
#
#      Class 0       0.54      0.93      0.69       250
#      Class 1       0.88      0.56      0.68       250
#      Class 2       0.94      0.13      0.23       250
#      Class 3       0.62      0.94      0.74       250
#
#     accuracy                           0.64      1000
#    macro avg       0.75      0.64      0.58      1000
# weighted avg       0.75      0.64      0.58      1000

# %% [markdown]
# # Part 5: Evaluation & Visualization
#
# This section loads the saved training history, plots loss/accuracy/LR curves, loads the best model checkpoint and runs it on the held-out test set, then displays a confusion matrix and a per-class classification report.

# %%
# ── Load history (works even if kernel was restarted after training) ──────────
history_path = f"{DRIVE_DIR}/history.json"
if 'history' not in dir() or not history["train_loss"]:
    with open(history_path) as f:
        history = json.load(f)

epochs = range(1, len(history["train_loss"]) + 1)
warmup_end = config["warmup_epochs"]

# ── Figure layout ─────────────────────────────────────────────────────────────
fig = plt.figure(figsize=(16, 10))
gs  = gridspec.GridSpec(2, 3, figure=fig, hspace=0.38, wspace=0.32)

ax_loss = fig.add_subplot(gs[0, 0])
ax_acc  = fig.add_subplot(gs[0, 1])
ax_lr   = fig.add_subplot(gs[0, 2])
ax_cm   = fig.add_subplot(gs[1, :2])
ax_rep  = fig.add_subplot(gs[1, 2])
ax_rep.axis("off")

# ── Helper: shade warmup region ───────────────────────────────────────────────
def shade_warmup(ax):
    ax.axvspan(1, warmup_end + 0.5, alpha=0.08, color="orange", label="warmup")
    ax.axvline(warmup_end + 0.5, color="orange", lw=0.8, ls="--")

# ── 1. Loss curves ────────────────────────────────────────────────────────────
ax_loss.plot(epochs, history["train_loss"], label="train", lw=2)
ax_loss.plot(epochs, history["val_loss"],   label="val",   lw=2, ls="--")
shade_warmup(ax_loss)
ax_loss.set_title("Loss")
ax_loss.set_xlabel("Epoch")
ax_loss.set_ylabel("Cross-entropy loss")
ax_loss.legend()
ax_loss.grid(alpha=0.3)

# ── 2. Accuracy curves ────────────────────────────────────────────────────────
ax_acc.plot(epochs, [a * 100 for a in history["train_acc"]], label="train", lw=2)
ax_acc.plot(epochs, [a * 100 for a in history["val_acc"]],   label="val",   lw=2, ls="--")
best_epoch = int(np.argmax(history["val_acc"])) + 1
best_acc   = max(history["val_acc"]) * 100
ax_acc.axvline(best_epoch, color="green", lw=1, ls=":", label=f"best val ({best_acc:.1f}%)")
shade_warmup(ax_acc)
ax_acc.set_title("Accuracy")
ax_acc.set_xlabel("Epoch")
ax_acc.set_ylabel("Accuracy (%)")
ax_acc.legend()
ax_acc.grid(alpha=0.3)

# ── 3. AUC curve (top-right panel) ───────────────────────────────────────────
if history.get("val_auc"):
    ax_lr.plot(epochs[:len(history["val_auc"])], history["val_auc"], color="teal", lw=2)
    shade_warmup(ax_lr)
    best_auc_ep = int(np.argmax(history["val_auc"])) + 1
    ax_lr.axvline(best_auc_ep, color="teal", lw=1, ls=":", label=f"best ({max(history['val_auc']):.4f})")
    ax_lr.set_title("Val Macro AUC")
    ax_lr.set_xlabel("Epoch")
    ax_lr.set_ylabel("AUC")
    ax_lr.legend()
else:
    ax_lr.plot(epochs, history["lr"], color="purple", lw=2)
    shade_warmup(ax_lr)
    ax_lr.set_title("Learning Rate Schedule")
    ax_lr.set_xlabel("Epoch")
    ax_lr.set_ylabel("LR")
    ax_lr.set_yscale("log")
ax_lr.grid(alpha=0.3)

# ── 4. Confusion matrix on test set (best model) ──────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_ckpt = f"{DRIVE_DIR}/best_model.pt"
model.load_state_dict(torch.load(best_ckpt, map_location=device))
model.eval().to(device)

all_preds, all_labels = [], []
with torch.no_grad():
    for batch in val_loader:
        batch = batch.to(device)
        preds = model(batch).argmax(dim=-1).cpu().tolist()
        labs  = batch.y.squeeze().cpu().tolist()
        all_preds.extend(preds)
        all_labels.extend(labs if isinstance(labs, list) else [labs])

cm = confusion_matrix(all_labels, all_preds)
val_acc = (np.array(all_preds) == np.array(all_labels)).mean() * 100
all_probs_np = torch.cat([
    torch.softmax(model(batch.to(device)), dim=-1).cpu()
    for batch in val_loader
], dim=0).detach().numpy()
try:
    val_auc = roc_auc_score(all_labels, all_probs_np, multi_class="ovr", average="macro")
except ValueError:
    val_auc = float("nan")
print(f"Val Accuracy: {val_acc:.2f}%  |  Val Macro AUC: {val_auc:.4f}")

im = ax_cm.imshow(cm, interpolation="nearest", cmap="Blues")
fig.colorbar(im, ax=ax_cm, fraction=0.046, pad=0.04)
tick_marks = np.arange(config["n_classes"])
ax_cm.set_xticks(tick_marks)
ax_cm.set_yticks(tick_marks)
ax_cm.set_xticklabels([f"Pred {i}" for i in tick_marks])
ax_cm.set_yticklabels([f"True {i}" for i in tick_marks])
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax_cm.text(j, i, str(cm[i, j]), ha="center", va="center",
                   color="white" if cm[i, j] > cm.max() / 2 else "black", fontsize=13)
ax_cm.set_title(f"Confusion Matrix — Val Acc: {val_acc:.1f}%  AUC: {val_auc:.4f}")
ax_cm.set_ylabel("True label")
ax_cm.set_xlabel("Predicted label")

# ── 5. Classification report ──────────────────────────────────────────────────
report = classification_report(all_labels, all_preds,
                               target_names=[f"Class {i}" for i in range(config["n_classes"])])
ax_rep.text(0.02, 0.98, report, transform=ax_rep.transAxes,
            fontsize=9, verticalalignment="top", fontfamily="monospace",
            bbox=dict(boxstyle="round", facecolor="whitesmoke", alpha=0.8))
ax_rep.set_title("Classification Report")

plt.suptitle(f"GQMoE Results — {config['wandb_run']}  |  Val Acc {val_acc:.1f}%  AUC {val_auc:.4f}", fontsize=13, y=1.01)

plot_path = f"{DRIVE_DIR}/results.png"
plt.savefig(plot_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Plot saved to: {plot_path}")
# Out:
# Val Accuracy: 84.04%  |  Val Macro AUC: 0.9301
# Plot saved to: /content/drive/MyDrive/GQMoE/results.png
